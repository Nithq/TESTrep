# %% [markdown]
# # Write a python program to create a base class "Shape" with methods to calculate area and perimeter.Then create derived classes "circle" and "Rectangle" that inherit from the base class and calculate their respective areas and perimeters.Demonstrate their usage in a python program
# You are developing an online quiz application where users can take quizzes on various topics and receive scores
# 1.Create a class for quizzes and questions
# 2.Implement a scoring system that calculates the user's score on a quiz
# 3. How would you store and retrieve user programs,including quiz history and scores?

# %%
import math

class Shape:
    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2

    def calculate_perimeter(self):
        return 2 * math.pi * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

# Demonstrate usage
circle = Circle(6)
rectangle = Rectangle(8, 12)

print(f"Circle - Area: {circle.calculate_area()}, Perimeter: {circle.calculate_perimeter()}")
print(f"Rectangle - Area: {rectangle.calculate_area()}, Perimeter: {rectangle.calculate_perimeter()}")
# Out:
# Circle - Area: 113.09733552923255, Perimeter: 37.69911184307752
# Rectangle - Area: 96, Perimeter: 40

# %% [markdown]
# # QN 2

# %%
class Question:
    def __init__(self, text, options, correct_option):
        self.text = text
        self.options = options
        self.correct_option = correct_option

class Quiz:
    def __init__(self, name):
        self.name = name
        self.questions = []

    def add_question(self, question):
        self.questions.append(question)

    def take_quiz(self):
        score = 0
        for question in self.questions:
            print(question.text)
            for i, option in enumerate(question.options):
                print(f"{i + 1}. {option}")
            user_answer = int(input("Your answer (1, 2, 3, ...): ")) - 1
            if user_answer == question.correct_option:
                print("Correct!")
                score += 1
            else:
                print("Incorrect!")
        print(f"Your score on '{self.name}' quiz: {score}/{len(self.questions)}")

# Example usage:
q1 = Question("What is the capital of India?", ["New Delhi", "Chennai", "Mumbai"], 0)
q2 = Question("Who is our current prime Minister?", ["Gopal", "Modi", "Vembu"], 1)

quiz1 = Quiz("General Knowledge")
quiz1.add_question(q1)
quiz1.add_question(q2)

quiz1.take_quiz()
# Out:
# What is the capital of India?
# 1. New Delhi
# 2. Chennai
# 3. Mumbai
# Your answer (1, 2, 3, ...): 1
# Correct!
# Who is our current prime Minister?
# 1. Gopal
# 2. Modi
# 3. Vembu
# Your answer (1, 2, 3, ...): 2
# Correct!
# Your score on 'General Knowledge' quiz: 2/2

# %% [markdown]
# # write a python script to create a class Person with private attributes for age and name.
# Implement a method to calculate a person's eligibility for voting based on their age.Ensure that age cannot be accessed directly but only through a getter method.

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    def is_eligible_to_vote(self):
        return self.__age >= 18


# Usage example:
if __name__ == "__main__":
    person1 = Person("Nithin", 67)
    person2 = Person("Hardik", 15)

    print(f"{person1.get_name()} is {person1.get_age()} years old.")
    if person1.is_eligible_to_vote():
        print(f"{person1.get_name()} is eligible to vote.")
    else:
        print(f"{person1.get_name()} is not eligible to vote.")

    print(f"{person2.get_name()} is {person2.get_age()} years old.")
    if person2.is_eligible_to_vote():
        print(f"{person2.get_name()} is eligible to vote.")
    else:
        print(f"{person2.get_name()} is not eligible to vote.")
# Out:
# Nithin is 67 years old.
# Nithin is eligible to vote.
# Hardik is 15 years old.
# Hardik is not eligible to vote.

# %% [markdown]
# # 3.You are tasked with designing a Python class hierarchy for a simple banking system.The system should be able to handle different types of accounts, such as saving accounts and checking accounts.Both account types should have common attributes like an account number, account holder's name and balance.However savings accounts should have an additional attribute for interest rate. while checking accounts should have an attribute for interest rate, while checking accounts should have an attribute for overdraft limit.
# 1.Create a Python class called Bankaccount with the following attributes and methods
#     a)Attributes : account_number,account_holder_name,balance
#     b)Methods:__init__()(constructor),deposit() and withdraw()
# 2.create two subclasses,Savings account and Checking Account, that inherit from the BankAccount class
# 3.Add the following attributes and methods to each subclass
#     a)SavingsAccount:
#         1)Additional attribute: interest_rate
#         2)Method-Calculate_interest(),which calculates and adds interest to the account based on the interest rate
#     b)CheckingAccount:
#         i) Additional attribute : Overdraft_limit
#         ii)Method: withdraw(),which allows withdrawing money upto the overdraft limit (if available) without additional fees
# 4.Write a program that creates instances of both SavingsAccount and CheckingAccount and demonstrates the use of their methods
# 5.Implement proper encapsulation by making the attributes private where necessary and providing getter and setter methods as needed
# 6.Handle any potential errors or exceptions that may occur during operations like withdrawals,deposits or interest calculations
# Your code should create instances of the classes,simulate transactions and showcase the differences between Savings account and Checking accounts

# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            return f"Deposited {amount}. New balance: {self.balance}"
        else:
            return "Invalid deposit amount"

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            return f"Withdrew {amount}. New balance: {self.balance}"
        else:
            return "Insufficient funds or invalid withdrawal amount"

    def get_balance(self):
        return f"Account balance for {self.account_holder_name}: {self.balance}"


class SavingsAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, interest_rate):
        super().__init__(account_number, account_holder_name, balance)
        self.interest_rate = interest_rate

    def apply_interest(self):
        interest = self.balance * (self.interest_rate / 100)
        self.balance += interest
        return f"Interest of {interest} applied. New balance: {self.balance}"


class CheckingAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, overdraft_limit):
        super().__init__(account_number, account_holder_name, balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if amount > 0 and amount <= (self.balance + self.overdraft_limit):
            self.balance -= amount
            return f"Withdrew {amount}. New balance: {self.balance}"
        else:
            return "Insufficient funds or invalid withdrawal amount"

    def get_overdraft_limit(self):
        return f"Overdraft limit for {self.account_holder_name}: {self.overdraft_limit}"


# Example usage:

savings_acc = SavingsAccount("SAV123", "Nithin", 1000, 3.0)
checking_acc = CheckingAccount("CHK456", "Raja", 500, 100)

print(savings_acc.deposit(500))
print(savings_acc.apply_interest())
print(savings_acc.get_balance())

print(checking_acc.withdraw(200))
print(checking_acc.get_overdraft_limit())
print(checking_acc.get_balance())
# Out:
# Deposited 500. New balance: 1500
# Interest of 45.0 applied. New balance: 1545.0
# Account balance for Nithin: 1545.0
# Withdrew 200. New balance: 300
# Overdraft limit for Raja: 100
# Account balance for Raja: 300

# %% [markdown]
# # 4. You are developing an employee management system for a company. Ensure that the system utilizes encapsulation and polymorphism to handle different types of employees, such as full-time and part-time employees.
# 1. Create a base called "Employee" with private attributes for name, employee ID and salary. Implement getter and setter methods for these attributes.
# 2. Design two subclasses, "FullTimeEmployee" and "PartTimeEmployee", that inherit from "Employee". These subclasses should encapsulate specific properties like hours worked (for part-time employees) and annual salary (for full-time employees).
# 3. Override the salary calculation method in both subclasses to account for different payment structures.
# 4. Write a program that demonstrates polymorphism by creating instances of both "FullTimeEmployee" and "PartTimeEmployee". Calculate their salaries and display employee information.

# %%
class Employee:
    def __init__(self, name, employee_id, salary):
        self.__name = name
        self.__employee_id = employee_id
        self.__salary = salary

    def get_name(self):
        return self.__name

    def get_employee_id(self):
        return self.__employee_id

    def get_salary(self):
        return self.__salary

    def set_name(self, name):
        self.__name = name

    def set_employee_id(self, employee_id):
        self.__employee_id = employee_id

    def set_salary(self, salary):
        self.__salary = salary

    def calculate_salary(self):
        pass

class FullTimeEmployee(Employee):
    def __init__(self, name, employee_id, annual_salary):
        super().__init__(name, employee_id, 0)  # Full-time employees get paid monthly, initialize with 0 balance
        self.__annual_salary = annual_salary

    def get_annual_salary(self):
        return self.__annual_salary

    def calculate_salary(self):
        self.set_salary(self.__annual_salary / 12)  # Monthly salary for full-time employees

class PartTimeEmployee(Employee):
    def __init__(self, name, employee_id, hourly_rate, hours_worked):
        super().__init__(name, employee_id, 0)  # Part-time employees get paid hourly, initialize with 0 balance
        self.__hourly_rate = hourly_rate
        self.__hours_worked = hours_worked

    def get_hourly_rate(self):
        return self.__hourly_rate

    def get_hours_worked(self):
        return self.__hours_worked

    def calculate_salary(self):
        self.set_salary(self.__hourly_rate * self.__hours_worked)  # Calculate salary based on hours worked

# Demonstration of polymorphism
full_time_employee = FullTimeEmployee("John", "FT1", 60000)
part_time_employee = PartTimeEmployee("Darlin", "PT1", 15, 80)

employees = [full_time_employee, part_time_employee]

for employee in employees:
    employee.calculate_salary()
    print(f"Employee ID: {employee.get_employee_id()}")
    print(f"Name: {employee.get_name()}")
    print(f"Monthly Salary: {employee.get_salary()}\n")
# Out:
# Employee ID: FT1
# Name: John
# Monthly Salary: 5000.0
#
# Employee ID: PT1
# Name: Darlin
# Monthly Salary: 1200

# %% [markdown]
# # 5.Library management system scenario: You are developing a library management system where you need to handle books, patrons and library transactions.
# 1. Create a class hierarchy that includes classes for books (e.g., Book), patrons (e.g., Patron), and transactions (e.g.,Transaction). Define attributes and methods for each class.
# 2. Implement encapsulation by making relevant attributes private and providing getter and setter methods where necessary.
# 3. Use inheritance to represent different type of books (e.g., fiction, non-fiction) as subclasses of the Book class. Ensure that each book type can have specific attributes and methods.
# 4. Demonstrate polymorphism by allowing patrons to check out and return books, regardlessof thebook type.
# 5. Implement a method for tracking overdue books and notifying patrons.
# 6. Consider scenarios like book reservations, late fees and library staff interactions inyour design.

# %%
import datetime

class Book:
    def __init__(self, title, author, isbn, total_copies):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.total_copies = total_copies
        self.available_copies = total_copies
        self.reserved_by = None

    def reserve(self, patron):
        if self.available_copies > 0:
            self.reserved_by = patron
            return True
        else:
            return False

    def unreserve(self):
        self.reserved_by = None

    def check_out(self):
        if self.available_copies > 0 and not self.reserved_by:
            self.available_copies -= 1
            return True
        else:
            return False

    def return_book(self):
        if self.available_copies < self.total_copies:
            self.available_copies += 1
            return True
        else:
            return False

    def is_overdue(self, due_date):
        return datetime.date.today() > due_date


class FictionBook(Book):
    def __init__(self, title, author, isbn, total_copies, genre):
        super().__init__(title, author, isbn, total_copies)
        self.genre = genre


class NonFictionBook(Book):
    def __init__(self, title, author, isbn, total_copies, subject):
        super().__init__(title, author, isbn, total_copies)
        self.subject = subject


class Patron:
    def __init__(self, name, patron_id):
        self.name = name
        self.patron_id = patron_id
        self.checked_out_books = []

    def check_out_book(self, book):
        if book.check_out():
            self.checked_out_books.append(book)
            return True
        else:
            return False

    def return_book(self, book):
        if book.return_book() and book in self.checked_out_books:
            self.checked_out_books.remove(book)
            return True
        else:
            return False


class Transaction:
    def __init__(self, patron, book, due_date):
        self.patron = patron
        self.book = book
        self.due_date = due_date

    def is_overdue(self):
        return self.book.is_overdue(self.due_date)

    def calculate_late_fee(self):
        if self.is_overdue():
            days_overdue = (datetime.date.today() - self.due_date).days
            return days_overdue * 1.00  # Adjust the late fee calculation as needed

    def notify_overdue(self):
        if self.is_overdue():
            print(f"Dear {self.patron.name}, your book '{self.book.title}' is overdue.")
            late_fee = self.calculate_late_fee()
            if late_fee:
                print(f"Please pay a late fee of ${late_fee} at the library.")

# %%
# Creating book instances
fiction_book = FictionBook("The Great Gatsby", "F. Scott Fitzgerald", "978-0743273565", 5, "Classic")
nonfiction_book = NonFictionBook("Sapiens", "Yuval Noah Harari", "978-0062316097", 3, "History")

# Creating patron instances
patron1 = Patron("Alice", 1)
patron2 = Patron("Bob", 2)

# Patrons checking out books
patron1.check_out_book(fiction_book)
patron2.check_out_book(nonfiction_book)

# Creating transactions
due_date = datetime.date.today() + datetime.timedelta(days=14)
transaction1 = Transaction(patron1, fiction_book, due_date)
transaction2 = Transaction(patron2, nonfiction_book, due_date)

# Notifying patrons about overdue books
transaction1.notify_overdue()  # No notification if not overdue
transaction2.notify_overdue()  # No notification if not overdue

# Patrons returning books
patron1.return_book(fiction_book)
patron2.return_book(nonfiction_book)
# Out:
# True

# %% [markdown]
# # 6.ONLINE SHOPPING CART
# Scenario: You are tasked with designing a class hierarchy for an online shopping cart system.The system should handle products,shopping carts and orders.Consider various OOP principles while designing this system.
#     1.Create a class hierarchy that includes classes for products(e.g., Product),shopping carts(e.g.,ShoppingCart), and orders (e.g.,Order).Define attributes and methods for each class.
#     2.Implement encapsulation by making relevant attributes private and providing getter and setter methods where necessary
#     3.Use Inheritance to represent different types of products(e.g.,electronics,clothing)as subclasses of the product class.Ensure that each product type have specific attributes and methods
#     4.Demonstrate polymorphism by allowing various product types to be added to a shopping cart and calculate the total cost of items in the cart.
#     5.Implement a method for placing an order, which transfers items from the shopping cart to an order
#     Consider scenarios like out-of-stock products,discounts and shipping costs in your design

# %%
class Product:
    def __init__(self, product_id, name, price, stock_quantity):
        self.__product_id = product_id  # Private attribute
        self.__name = name  # Private attribute
        self.__price = price  # Private attribute
        self.__stock_quantity = stock_quantity  # Private attribute

    # Getter and setter methods for product attributes
    def get_product_id(self):
        return self.__product_id

    def get_name(self):
        return self.__name

    def get_price(self):
        return self.__price

    def get_stock_quantity(self):
        return self.__stock_quantity

    def set_stock_quantity(self, new_quantity):
        self.__stock_quantity = new_quantity

    def is_available(self, quantity):
        return self.__stock_quantity >= quantity


class ShoppingCart:
    def __init__(self):
        self.__items = []  # Private attribute to store items in the cart

    def add_item(self, product, quantity):
        """
        Add a product to the shopping cart.

        Parameters:
        - product (Product): The product to add.
        - quantity (int): The quantity of the product to add.

        Returns:
        - True if the product was successfully added, False otherwise.
        """
        if product.is_available(quantity):
            self.__items.append({"product": product, "quantity": quantity})
            product.set_stock_quantity(product.get_stock_quantity() - quantity)
            return True
        else:
            return False

    def calculate_total_cost(self):
        """
        Calculate the total cost of items in the shopping cart.

        Returns:
        - The total cost of items in the cart.
        """
        total_cost = 0
        for item in self.__items:
            product = item["product"]
            quantity = item["quantity"]
            total_cost += product.get_price() * quantity
        return total_cost

    def clear_cart(self):
        """
        Clear the shopping cart.
        """
        self.__items.clear()


class Order:
    def __init__(self, order_id, customer_name, shipping_address):
        self.__order_id = order_id  # Private attribute
        self.__customer_name = customer_name  # Private attribute
        self.__shipping_address = shipping_address  # Private attribute
        self.__items = []  # Private attribute to store items in the order

    def add_item(self, product, quantity):
        """
        Add a product to the order.

        Parameters:
        - product (Product): The product to add to the order.
        - quantity (int): The quantity of the product to add.

        Returns:
        - True if the product was successfully added to the order, False otherwise.
        """
        self.__items.append({"product": product, "quantity": quantity})
        return True

    def calculate_order_total(self):
        """
        Calculate the total cost of the order.

        Returns:
        - The total cost of the order.
        """
        total_cost = 0
        for item in self.__items:
            product = item["product"]
            quantity = item["quantity"]
            total_cost += product.get_price() * quantity
        return total_cost

    def place_order(self):
        """
        Place the order, which may involve additional processes like applying discounts and calculating shipping costs.
        """
        # Additional logic for discounts, shipping costs, etc. can be added here
        pass


# Example usage:

# Create some products
product1 = Product(1, "Smartphone", 499.99, 10)
product2 = Product(2, "Laptop", 899.99, 5)
product3 = Product(3, "T-shirt", 19.99, 50)

# Create a shopping cart
cart = ShoppingCart()

# Add products to the cart
cart.add_item(product1, 2)
cart.add_item(product2, 1)
cart.add_item(product3, 5)

# Calculate the total cost in the cart
total_cost_in_cart = cart.calculate_total_cost()
print(f"Total cost in the cart: {total_cost_in_cart}")

# Create an order and add products to it
order = Order(101, "John Doe", "123 Main St")
order.add_item(product1, 2)
order.add_item(product2, 1)
order.add_item(product3, 5)

# Calculate the total cost of the order
total_cost_of_order = order.calculate_order_total()
print(f"Total cost of the order: {total_cost_of_order}")

# Place the order (additional logic can be implemented here)
order.place_order()

# Clear the shopping cart after placing the order
cart.clear_cart()
# Out:
# Total cost in the cart: 1999.92
# Total cost of the order: 1999.92
